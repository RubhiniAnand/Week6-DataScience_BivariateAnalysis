# %%
import pandas as pd

# %%
dataset=pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
dataset.loc[:,"status"]
# Out:
# 0          Placed
# 1          Placed
# 2          Placed
# 3      Not Placed
# 4          Placed
#           ...
# 210        Placed
# 211        Placed
# 212        Placed
# 213        Placed
# 214    Not Placed
# Name: status, Length: 215, dtype: object

# %% [markdown]
# #**1.Replace the NAN values with correct values and justify why you have chosen the same??**

# %%
dataset["salary"].fillna(0,inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2232\2080798296.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["salary"].fillna(0,inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnname in dataset.columns:
            #print(columnname)
        if(dataset[columnname].dtype=='O'):
            #print("qual")
            qual.append(columnname)
        else:
           # print("quan")
            quan.append(columnname)
    return quan,qual

# %%
quan,qual=quanQual(dataset)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
def findOutliers(descriptive,quan):
        lesser=[]
        greater=[]
        for columnName in quan:
            if(descriptive[columnName]["Min"]<descriptive[columnName]["Lesser"]):
                lesser.append(columnName)
            if(descriptive[columnName]["Max"]>descriptive[columnName]["Greater"]):
                greater.append(columnName)
        return lesser,greater

# %% [markdown]
# #**2.How many of them are not placed?**

# %%
NotPlaced_count=dataset[dataset['status']=='Not Placed'].shape[0]

# %%
print("The total number of students not placed in a job are:",NotPlaced_count)
# Out:
# The total number of students not placed in a job are: 67

# %%
notPlaced_ds=dataset[dataset['status']=='Not Placed']

# %%
notPlaced_ds
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 3        4      M   56.0  Central   52.0  Central   Science     52.00
# 5        6      M   55.0   Others   49.8   Others   Science     67.25
# 6        7      F   46.0   Others   49.2   Others  Commerce     79.00
# 9       10      M   58.0  Central   70.0  Central  Commerce     61.00
# 12      13      F   47.0  Central   55.0   Others   Science     65.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 198    199      F   67.0  Central   70.0  Central  Commerce     65.00
# 201    202      M   54.2  Central   63.0   Others   Science     58.00
# 206    207      M   41.0  Central   42.0  Central   Science     60.00
# 208    209      F   43.0  Central   60.0   Others   Science     65.00
# 214    215      M   62.0  Central   58.0   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
placed_ds=dataset[dataset['status']=='Placed']

# %%
placed_ds
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# 7        8      M  82.00  Central  64.00  Central   Science     66.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# ...

# %%
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     215.000000
# mean   198702.325581
# std    154780.926716
# min         0.000000
# 25%         0.000000
# 50%    240000.000000
# 75%    282500.000000
# max    940000.000000

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"],columns=quan)
for columnName in quan:
        descriptive.loc["Mean",columnName]=dataset[columnName].mean()
        descriptive.loc["Median",columnName]=dataset[columnName].median()
        descriptive.loc["Mode",columnName]=dataset[columnName].mode()[0]
        descriptive.loc["Q1:25%",columnName]=dataset.describe()[columnName]["25%"]
        descriptive.loc["Q2:50%",columnName]=dataset.describe()[columnName]["50%"]
        descriptive.loc["Q3:75%",columnName]=dataset.describe()[columnName]["75%"]
        descriptive.loc["Q4:100%",columnName]=dataset.describe()[columnName]["max"]    
        descriptive.loc["IQR",columnName]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
        descriptive.loc["1.5rule",columnName]=1.5*descriptive[columnName]["IQR"]
        descriptive.loc["Lesser",columnName]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
        descriptive.loc["Greater",columnName]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
        descriptive.loc["Min",columnName]=dataset[columnName].min()
        descriptive.loc["Max",columnName]=dataset[columnName].max()

# %%
descriptive
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean     108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median   108.0       67.0       65.0       66.0       71.0       62.0
# Mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%   108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%   161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%  215.0       89.4       97.7       91.0       98.0      77.89
# IQR      107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule  160.5      22.65      18.15       16.5      35.25     12.465
# Lesser  -106.0      37.95      42.75       44.5      24.75      45.48
# Greater  322.0      98.35      91.15       88.5     118.75      78.72
# Min          1      40.89       37.0       50.0       50.0      51.21
# ...

# %%
def findOutliers(descriptive,quan):
        lesser=[]
        greater=[]
        for columnName in quan:
            if(descriptive[columnName]["Min"]<descriptive[columnName]["Lesser"]):
                lesser.append(columnName)
            if(descriptive[columnName]["Max"]>descriptive[columnName]["Greater"]):
                greater.append(columnName)
        return lesser,greater

# %%
lesser,greater=findOutliers(descriptive,quan)

# %%
greater
# Out:
# ['hsc_p', 'degree_p', 'salary']

# %%
lesser
# Out:
# ['hsc_p']

# %%
#function to replace outliers
for column in lesser:
    dataset[column][dataset[column]<descriptive[column]["Lesser"]]=descriptive[column]["Lesser"]
for column in greater:
    dataset[column][dataset[column]>descriptive[column]["Greater"]]=descriptive[column]["Greater"]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2232\3892904300.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dataset[column][dataset[column]<descriptive[column]["Lesser"]]=descriptive[column]["Lesser"]
# ...

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode","Q1:25%","Q2:50%","Q3:75%","Q4:100%","IQR","1.5rule","Lesser","Greater","Min","Max"],columns=quan)
for columnName in quan:
        descriptive.loc["Mean",columnName]=dataset[columnName].mean()
        descriptive.loc["Median",columnName]=dataset[columnName].median()
        descriptive.loc["Mode",columnName]=dataset[columnName].mode()[0]
        descriptive.loc["Q1:25%",columnName]=dataset.describe()[columnName]["25%"]
        descriptive.loc["Q2:50%",columnName]=dataset.describe()[columnName]["50%"]
        descriptive.loc["Q3:75%",columnName]=dataset.describe()[columnName]["75%"]
        descriptive.loc["Q4:100%",columnName]=dataset.describe()[columnName]["max"]    
        descriptive.loc["IQR",columnName]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
        descriptive.loc["1.5rule",columnName]=1.5*descriptive[columnName]["IQR"]
        descriptive.loc["Lesser",columnName]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
        descriptive.loc["Greater",columnName]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
        descriptive.loc["Min",columnName]=dataset[columnName].min()
        descriptive.loc["Max",columnName]=dataset[columnName].max()

# %%
descriptive
# Out:
#          sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean     108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# Median   108.0       67.0       65.0       66.0       71.0       62.0
# Mode         1       62.0       63.0       65.0       60.0       56.7
# Q1:25%    54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%   108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%   161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%  215.0       89.4      91.15       88.5       98.0      77.89
# IQR      107.0       15.1       12.1       11.0       23.5       8.31
# 1.5rule  160.5      22.65      18.15       16.5      35.25     12.465
# Lesser  -106.0      37.95      42.75       44.5      24.75      45.48
# Greater  322.0      98.35      91.15       88.5     118.75      78.72
# Min          1      40.89      42.75       50.0       50.0      51.21
# ...

# %%
def findOutliers(descriptive,quan):
        lesser=[]
        greater=[]
        for columnName in quan:
            if(descriptive[columnName]["Min"]<descriptive[columnName]["Lesser"]):
                lesser.append(columnName)
            if(descriptive[columnName]["Max"]>descriptive[columnName]["Greater"]):
                greater.append(columnName)
        return lesser,greater

# %%
lesser,greater=findOutliers(descriptive,quan)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# []

# %% [markdown]
# #**3.Find the reason for non placement from the dataset**

# %% [markdown]
# ##**Students those who were placed has scored above the average marks in all the exams compared to the students who are not placed.
#
# The mean ssc_p marks of the students who are not placed are generally lower than those who are placed. For example, the mean ssc_p marks for students who are not placed is approximately 57.5, while for those who are placed, it's approximately 71.7.
#
# Some standard deviation of the exam marks for students who are not placed is generally higher compared to those who are placed. This suggests that
# there is more variability in the exam marks of students who are not placed.
#
# 25% - 50% of not placed students marks are bewtween 51 to 67 which is lower compare to the marks of placed students
#
# The placed students minimum marks starts from 49 to 52 while the not placed students minimum marks are from 37 to 51.
#
# Based on this analysis, it appears that students who are not placed tend to have lower academic performance,in terms of  all exam marks compared to those who are placed. This lower academic performance could be one of the reasons why these students are not getting placed**

# %%
notPlaced_ds.describe()
# Out:
#             sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# count   67.000000  67.000000  67.000000  67.000000  67.000000  67.000000
# mean   110.477612  57.544030  58.395522  61.134179  69.587910  61.612836
# std     65.859667   8.394246   9.914090   6.365825  11.930687   5.705689
# min      4.000000  40.890000  37.000000  50.000000  50.000000  51.210000
# 25%     48.500000  52.000000  51.000000  57.000000  60.000000  58.480000
# 50%    107.000000  56.280000  60.330000  61.000000  67.000000  60.690000
# 75%    170.500000  63.000000  64.000000  65.000000  76.500000  65.405000
# max    215.000000  77.800000  82.000000  79.000000  97.000000  75.710000
#
#        salary
# count    67.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0

# %%
placed_ds.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  148.000000  148.000000  148.000000  148.000000  148.000000  148.000000
# mean   106.878378   71.721486   69.926554   68.740541   73.238041   62.579392
# std     60.682502    8.715445    9.329268    6.518087   13.729333    5.884583
# min      1.000000   49.000000   50.830000   56.000000   50.000000   52.380000
# 25%     57.750000   65.000000   63.000000   65.000000   60.000000   57.772500
# 50%    108.500000   72.500000   68.000000   68.000000   72.000000   62.245000
# 75%    153.250000   78.125000   75.250000   72.422500   85.000000   66.760000
# max    214.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %% [markdown]
# #**4.What kind of relation b/w mba_p and salary?**

# %%
corrSalary_mba=dataset['salary'].corr(dataset['mba_p'])

# %%
print("The relation between the salary and mba_p mark is:",corrSalary_mba)
# Out:
# The relation between the salary and mba_p mark is: 0.14141713944325937

# %% [markdown]
# #**5.Which specialization is getting minimum salary?**

# %%
min_Salary=placed_ds['salary'].min()

# %%
spec_minSalary=dataset.loc[dataset['salary']==min_Salary,'specialisation'].iloc[0]

# %%
print("The specializsation with minimum salary is:",spec_minSalary)
# Out:
# The specializsation with minimum salary is: Mkt&Fin

# %% [markdown]
# #**6.How many of them getting salary above 50000?**

# %%
Salary1=dataset[dataset['salary']>50000].shape[0]

# %%
print(Salary1,"students are getting salary above 50000")
# Out:
# 148 students are getting salary above 50000

# %% [markdown]
# **#7.Test the Analysis of Variance between etest_p and mba_p at signifance level 5%.(Make decision using Hypothesis Testing)**

# %%
import scipy.stats as stats

stats.f_oneway(dataset['mba_p'],dataset['etest_p'])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %% [markdown]
# #if pvalue < 0.05
# #Ho: There is no significant difference between etest_p and mba_p mark

# %% [markdown]
# #H1: There is a significant difference between etest_p and mba_p mark

# %% [markdown]
# ##**here,pvalue>0.05 hence Accept Null Hypothesis :There is no significant difference between etest_p and mba_p mark**

# %% [markdown]
# #**8.Test the similarity between the degree_t(Sci&Tech) and specialisation(Mkt&HR) with respect to salary
# at significance level of 5%.(Make decision using Hypothesis Testing)**

# %%
from scipy.stats import ttest_ind
dataset=dataset.dropna()
sciTech =dataset[dataset['degree_t']=='Sci&Tech']['salary']
mkHr =dataset[dataset['specialisation']=='Mkt&HR']['salary']
ttest_ind(sciTech,mkHr)
# Out:
# TtestResult(statistic=2.692041243555374, pvalue=0.007897969943471179, df=152.0)

# %% [markdown]
# #if pvalue < 0.05
# #Ho: There is no significant difference between etest_p and mba_p mark

# %% [markdown]
# #H1: There is a significant difference between etest_p and mba_p mark

# %% [markdown]
# ##**here, pvalue<0.05 hence Reject Null Hypothesis :There is a significant difference between etest_p and mba_p mark**

# %% [markdown]
# #H1: There is a significant difference between etest_p and mba_p mark

# %% [markdown]
# ##**9.Convert the normal distribution to standard normal distribution for salary column**

# %%
import seaborn as sns

# %%
sns.distplot(dataset["salary"])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2232\2049611699.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["salary"])
# <Axes: xlabel='salary', ylabel='Density'>

# %%
def stdNBgraph(dataset):
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()

    values=[i for i in dataset]

    z_score=[((j-mean)/std) for j in values]

    sns.distplot(z_score,kde=True)

    sum(z_score)/len(z_score)
    #z_score.std()

# %%
stdNBgraph(dataset["salary"])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2232\4190665762.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(z_score,kde=True)

# %% [markdown]
# #**10.What is the probability Density Function of the salary range from 700000 to 900000?**

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset["salary"],700000,900000)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2232\2842244316.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
# Mean=197615.116, Standard Deviation=150305.844
# The area between range(700000,900000):0.0004137812663830048
# 0.0004137812663830048

# %% [markdown]
# ##0.04% of students have got salary between 700000 and 900000

# %% [markdown]
# #**11.Test the similarity between the degree_t(Sci&Tech)with respect to etest_p and mba_p
# at significance level of 5%.(Make decision using Hypothesis Testing)**

# %%
from scipy.stats import ttest_rel
#dataset=dataset.dropna()
sciTech1 = dataset[dataset['degree_t']=='Sci&Tech']['etest_p']
sciTech2 = dataset[dataset['degree_t']=='Sci&Tech']['mba_p']
ttest_rel(sciTech1,sciTech2)
# Out:
# TtestResult(statistic=5.0049844583693615, pvalue=5.517920600505392e-06, df=58)

# %% [markdown]
# #if pvalue < 0.05
# #Ho: There is no significant difference between etest_p and mba_p mark

# %% [markdown]
# #H1: There is a significant difference between etest_p and mba_p mark

# %% [markdown]
# ##**here,pvalue > 0.05 hence Accept Null Hypothesis :There is no significant difference in etest_p and mba_p marks with respect to degree undertaken**

# %% [markdown]
# #**12.Which parameter is highly correlated with salary**?

# %%
correlation_coef=dataset.corr(numeric_only=True)['salary']

# %%
correlation_coef

# %%
sorted=correlation_coef.sort_values(ascending=False)

# %%
sorted

# %% [markdown]
# #ssc_p variable is 55% correlated with salary variable

# %% [markdown]
# ##**13.plot any useful graph and explain it**

# %%
sns.pairplot(dataset)

# %%
sns.pairplot(dataset)
